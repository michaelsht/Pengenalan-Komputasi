# %%
# NIM/NAMA  : 16521201/Michael Sihotang
# Tanggal   : 01 Desember 2021
# Deskripsi : Problem 2 Analisis dan Visualisasi Data "P05-01.csv"

# %%
# Nomor 1
# Banyaknya pengguna tidak aktif yang berusia di atas 50 tahun
import pandas as pd

# Pandas akan membaca file P05-01.csv yang berada di folder yang sama dengan file ipynb ini
df = pd.read_csv("P05-01.csv")
df1 = df.loc[df["Attrition_Flag"] == "Attrited Customer"]
A = df1.loc[df1["Customer_Age"] > 50]

# Menampilkan banyaknya pengguna tidak aktif yang berusia di atas 50 tahun
print("Banyaknya pengguna tidak aktif yang berusia di atas 50 tahun: ", len(A))
# Out:
# Banyaknya pengguna tidak aktif yang berusia di atas 50 tahun:  506

# %%
# Nomor 2
# ID pengguna dengan nominal limit kartu kredit terbesar
import pandas as pd

# Pandas akan membaca file P05-01.csv yang berada di folder yang sama dengan file ipynb ini
df2 = pd.read_csv("P05-01.csv")
kredit_max = df2["Credit_Limit"].max()

# Menampilkan ID pengguna dengan nominal limit kartu kredit terbesar
df2.loc[df2["Credit_Limit"] == kredit_max]
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 6      810347208  Existing Customer            51      M                4
# 45     712661433  Existing Customer            49      M                4
# 61     712030833  Attrited Customer            48      M                2
# 65     788979258  Existing Customer            51      M                4
# 70     715971108  Existing Customer            51      M                4
# ...          ...                ...           ...    ...              ...
# 10088  709188108  Existing Customer            45      M                2
# 10095  789023508  Existing Customer            46      M                3
# 10098  716644008  Attrited Customer            55      M                3
# 10110  718225683  Existing Customer            56      M                1
# 10112  708564858  Attrited Customer            33      M                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
# Nomor 3
# Banyaknya pengguna dengan tipe kartu Blue dan lama penggunaan kartu kredit dalam bulan di atas 40
import pandas as pd

# Pandas akan membaca file P05-01.csv yang berada di folder yang sama dengan file ipynb ini
df3 = pd.read_csv("P05-01.csv")
B= df3.loc[(df3["Card_Category"] == "Blue") & (df3["Months_on_book"] > 40)]
# Menampilkan banyaknya pengguna dengan tipe kartu Blue dan lama penggunaan kartu kredit dalam bulan di atas 40
print("banyaknya pengguna dengan tipe kartu Blue dan lama penggunaan kartu kredit dalam bulan di atas 40: ", len(B))
# Out:
# banyaknya pengguna dengan tipe kartu Blue dan lama penggunaan kartu kredit dalam bulan di atas 40:  2348

# %%
# Nomor 4
# Banyaknya pengguna dengan total nominal yang belum dibayar pengguna kartu kredit sama dengan 0 untuk masing-masing kategori penghasilan.
import pandas as pd

# Pandas akan membaca file P05-01.csv yang berada di folder yang sama dengan file ipynb ini
df = pd.read_csv("P05-01.csv")

# Menampilkan banyaknya pengguna dengan total nominal yang belum dibayar pengguna kartu kredit sama dengan 0 untuk masing-masing kategori penghasilan.
df4 = df.loc[df["Total_Revolving_Bal"] == 0]
df4["Income_Category"].value_counts()
# Out:
# Less than $40K    899
# $40K - $60K       420
# $80K - $120K      344
# $60K - $80K       340
# Unknown           303
# $120K +           164
# Name: Income_Category, dtype: int64

# %%
# Nomor 5
# 5 ID pengguna aktif dengan banyak bulan kartu kredit tidak aktif dalam 12 bulan terakhir terbanyak.
import pandas as pd

# Pandas akan membaca file P05-01.csv yang berada di folder yang sama dengan file ipynb ini
df = pd.read_csv("P05-01.csv")

# Menampilkan 5 ID pengguna aktif dengan banyak bulan kartu kredit tidak aktif dalam 12 bulan terakhir terbanyak.
df5 = df.loc[df["Attrition_Flag"] == "Existing Customer"]
df5.sort_values(["Months_Inactive_12_mon"], ascending=[False])[:5]
# Out:
#       CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 3220  709381383  Existing Customer            49      M                4
# 7589  710542983  Existing Customer            48      F                4
# 2060  789607983  Existing Customer            38      M                3
# 749   711668283  Existing Customer            48      M                4
# 6023  710864358  Existing Customer            51      F                2
#
#      Education_Level Marital_Status Income_Category Card_Category  \
# 3220        Graduate        Married     $60K - $80K          Blue
# 7589        Graduate        Married  Less than $40K          Blue
# 2060     High School        Married     $40K - $60K          Blue
# 749       Uneducated        Married    $80K - $120K          Blue
# 6023       Doctorate        Married         Unknown          Blue
#
#       Months_on_book  Months_Inactive_12_mon  Credit_Limit  \
# 3220              36                       6        2952.0
# ...
